# %%
import librosa
y, sr = librosa.load('data/train/DBA_9863_159.WAV', sr=None)
print(f"Sample rate: {sr}")
print(f"Duration: {len(y)/sr:.4f} seconds")
# Out:
# Sample rate: 250000
# Duration: 0.0416 seconds
